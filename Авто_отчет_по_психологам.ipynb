# %% [markdown]
# <a href="https://colab.research.google.com/github/Grottersha123/intellectual-psy-report/blob/master/%D0%90%D0%B2%D1%82%D0%BE_%D0%BE%D1%82%D1%87%D0%B5%D1%82_%D0%BF%D0%BE_%D0%BF%D1%81%D0%B8%D1%85%D0%BE%D0%BB%D0%BE%D0%B3%D0%B0%D0%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
cd /content/drive/My Drive/data_psyho
# Out:
# /content/drive/My Drive/data_psyho

# %%
import pandas as pd

# %%
#Загружаем данные 
psycho = pd.read_csv('psychologists.csv', sep=',', error_bad_lines=False, encoding='cp1251')
psycho = psycho.rename(columns=psycho.iloc[0])
psycho = psycho.iloc[1:]
completed = pd.read_csv('completed-psy.csv', sep=',', error_bad_lines=False, encoding='cp1251')
print(psycho.shape, completed.shape)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,4,5,15,40,41,46,47,52,53,58,59,64,65,70,71,76,77,82,83,88,89,94,95,100,101,106,107,112,113,118,119,124,125,130,131,141,142,147,148,153,154,159,160,165,166,171,172,177,178,183,184,189,190,200,201,206,207,212,213,218,219,224,225,230,231,236,237,242,243,248,249,254,255,260,261,266,267,272,273,278,279,284,285,290,291,296,297,302,303,308,309,314,315,325,326,331,332,337,338,343,344,349,350,355,356,361,362,367,368,373,374,379,380,385,386,391,392,397,398,408,409,414,415,420,421,426,427,432,433,438,439,444,445,455,456,461,462,467,468,473,474,479,480,485,486,496,497,502,503,508,509,514,515,525,526,531,532,537,538,543,544,549,550,555,556,561,562,567,568,573,574,579,580,585,586,591,592,597,598,603,604,609,610,615,616,621,622,627,628,633,634,639,640,645,646,651,652,657,658,663,664,669,670,675,676,681,682,687,688,693,694,699,700,710,711,716,717,722,723,728,729,734,735,740,741,746,747,752,753,758,
# ...

# %%
psycho.head(10)
# Out:
#                           id  ...          metadata.endTime
# 1   5ced03423ed9c329c57d754c  ...  2019-05-28T10:19:08.129Z
# 2   5ced559889d9740ae99b1019  ...  2019-05-28T20:38:36.514Z
# 3   5cee25b0b2f7ce29f9a2e230  ...  2019-05-29T07:06:09.838Z
# 4   5cee2aca3ed9c329c57d7555  ...  2019-05-29T08:44:39.908Z
# 5   5cee2ded05d7190ab5276fb9  ...  2019-05-29T08:43:26.279Z
# 6   5cee2f5ec2f2a229c6fb8ebd  ...  2019-05-29T07:18:09.406Z
# 7   5cee338d2bd2d30ab4c00632  ...  2019-05-29T08:05:30.300Z
# 8   5cee3888b2f7ce29f9a2e234  ...  2019-05-29T08:33:17.074Z
# 9   5cee47ac3ed9c329c57d755d  ...  2019-05-29T09:25:29.505Z
# 10  5cee4f593ed9c329c57d755e  ...  2019-05-29T09:50:39.777Z
#
# [10 rows x 1728 columns]

# %%
# Фильтр по Свердловской области, второй датасет фильтр по россии 
def prepare_data(region):
  psyho_reg = psycho[(psycho.region == str(region))  | (psycho.region == int(region)) ]
  psyho_russia = psycho[(psycho.region != str(region))  | (psycho.region != int(region)) ]
  clmt = list(psyho_reg.columns)
  columns = []
  for i in clmt:
    try:
      if i != None and'PQ' in i and not 'Time' in i and not 'order' in i:
        columns.append(i)
    except Exception as e:
      print(e, psyho_reg[i])
  psyho_reg_columns = psyho_reg[columns]
  psyho_russia_columns = psyho_russia[columns]
  print(psyho_russia_columns.shape, psyho_reg_columns.shape)
  return psyho_russia_columns, psyho_reg_columns

# %%
data_rus, data_reg = prepare_data(66)
# Out:
# argument of type 'numpy.float64' is not iterable 3        1.0
# 4        1.0
# 5        1.0
# 7        1.0
# 8        1.0
#         ...
# 14398    1.0
# 15331    1.0
# 15505    1.0
# 16017    1.0
# 16499    1.0
# Name: 501.0, Length: 575, dtype: float64
# (16854, 285) (575, 285)

# %%
# Первое что нужно сделать это выбрать данные нужные нам.

# %%
data_rus_10 = data_rus.iloc[:1000000]
data = data_rus_10.dropna()
#Делим вопросы со свободным ответом и с вариантом
def select_cloumns(data,data_all):
  clmns = data.columns
  dig = []
  for col in data.columns:
    try:
      for d in data[col]:
        if d.isdigit() and 'Other' not in col:
          dig.append(col)
          break
    except:
      print(d,col)
  not_dig = [i for i in clmns if i not in dig]
  return data_all[dig], data_all[not_dig]

# %%
data_rus_num, data_rus_text = select_cloumns(data, data_rus)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-b4f4ec75c3e1> in <module>()
# ----> 1 data_rus_num, data_rus_text = select_cloumns(data, data_rus)
#       2 data_reg['PQ101-01'].unique()
#
# <ipython-input-13-72a4bbf1e751> in select_cloumns(data, data_all)
#       3 #Делим вопросы со свободным ответом и с вариантом
#       4 def select_cloumns(data,data_all):
# ----> 5   clmns = data.columns
#       6   dig = []
#       7   for col in data.columns:
#
# AttributeError: 'list' object has no attribute 'columns'

# %%
# не понятно что делать со значениями, которые возможно имеют и не 4 варианта ответа
import numpy as np
import collections
def count_four_off(data):
  shape = data.astype(float).shape[0]
  print(shape)
  a = data.astype(float).value_counts(dropna=False)
  count_1 = a[1.0] + a[2.0]
  count_2 = a[3.0] + a[4.0]
  res1 = round(count_1 / shape * 100, 2)
  res2 = round(count_2/ shape * 100, 2)
  if len(a) == 5:
    res3 = round(a[np.nan] / shape * 100,2)
    return (count_1, count_2, a[np.nan]), (res1, res2, res3)
  else:
    return res1, res2, 0
# для 4-ех, но две метрици складываются
def count_four_1(data):
  shape = data.astype(float).shape[0]
  a = data.astype(float).replace({1.0: 2.0, 3.0: 4.0}).value_counts(dropna=False, normalize=True).mul(100).round(2)
  print(a)
  first = a[2.0] if 2.0 in a else 0
  second = a[4.0] if 4.0 in a else 0
  third = a[np.nan] if True in np.isnan(list(a.keys())) else 0
  return first, second, third
# для 4 ех ответов
def count_four_2(data):
  a = data.astype(float).value_counts(dropna=False, normalize=True).mul(100).round(2)
  print(a)
  first = a[1.0] if 1.0 in a else 0
  second = a[2.0] if 2.0 in a else 0
  third = a[3.0] if 3.0 in a else 0
  four = a[4.0] if 4.0 in a else 0
  five = a[np.nan] if True in np.isnan(list(a.keys())) else 0
  return first, second, third, four, five

def count_three(data):
  a = data.astype(float).value_counts(dropna=False, normalize=True).mul(100).round(2)
  print(a)
  first = a[1.0] if 1.0 in a else 0
  second = a[2.0] if 2.0 in a else 0
  third = a[3.0] if 3.0 in a else 0
  four = a[np.nan] if True in np.isnan(list(a.keys())) else 0
  return first, second, third, four


def count_five(data):
  a = data.astype(float).value_counts(dropna=False, normalize=True).mul(100).round(2)
  print(a)
  first = a[1.0] if 1.0 in a else 0
  second = a[2.0] if 2.0 in a else 0
  third = a[3.0] if 3.0 in a else 0
  four = a[4.0] if 4.0 in a else 0
  five = a[5.0] if 4.0 in a else 0
  six = a[np.nan] if True in np.isnan(list(a.keys())) else 0
  return first, second, third, four, five, six


def count_six(data):
  a = data.astype(float).value_counts(dropna=False, normalize=True).mul(100).round(2)
  print(a)
  first = a[1.0] if 1.0 in a else 0
  second = a[2.0] if 2.0 in a else 0
  third = a[3.0] if 3.0 in a else 0
  four = a[4.0] if 4.0 in a else 0
  five = a[5.0] if 5.0 in a else 0
  six = a[6.0] if 6.0 in a else 0
  seven = a[np.nan] if True in np.isnan(list(a.keys())) else 0
  return first, second, third, four, five, six, seven

def count_eight(data):
  a = data.astype(float).value_counts(dropna=False, normalize=True).mul(100).round(2)
  print(a)
  first = a[1.0] if 1.0 in a else 0
  second = a[2.0] if 2.0 in a else 0
  third = a[3.0] if 3.0 in a else 0
  four = a[4.0] if 4.0 in a else 0
  five = a[5.0] if 5.0 in a else 0
  six = a[6.0] if 6.0 in a else 0
  seven = a[7.0] if 7.0 in a else 0
  eight = a[8.0] if 8.0 in a else 0
  nine = a[np.nan] if True in np.isnan(list(a.keys())) else 0
  return first, second, third, four, five, six, seven, eight, nine

def count_two(data):
  a = data.astype(float).value_counts(dropna=False, normalize=True).mul(100).round(2)
  first = a[1.0] if 1.0 in a else 0
  second = a[2.0] if 2.0 in a else 0
  third = a[np.nan] if True in np.isnan(list(a.keys())) else 0
  return first, second, third


def count_str(data):
  a = data.astype(object)
  a = a.apply(lambda x: 1.0 if isinstance(x, str) else x)
  a = a.astype(float).value_counts(dropna=False, normalize=True).mul(100).round(2)
  first = a[1.0] if 1.0 in a else 0
  third = a[np.nan] if True in np.isnan(list(a.keys())) else 0
  return first, third


def count_all(data, len_var):
  a = a.astype(float).value_counts(dropna=False, normalize=True).mul(100).round(2)
  for i in range(1, len_var):

# %%
print(count_two(data_reg['PQ106-01']))
print(count_three(data_reg['PQ608']))
print(count_four_1(data_reg['PQ101-02']))
print(count_four_2(data_reg['PQ604-degree']))
print(count_five(data_reg['PQ613']))
print(count_six(data_reg['PQ605-major']))
print(count_eight(data_reg['PQ304-01']))
print(count_str(data_reg['PQ101-Other']))
# Out:
# (39.48, 60.52, 0)
# 3.0    43.65
# 2.0    39.13
# 1.0    16.52
# NaN     0.70
# Name: PQ608, dtype: float64
# (16.52, 39.13, 43.65, 0.7)
# 4.0    75.83
# 2.0    24.00
# NaN     0.17
# Name: PQ101-02, dtype: float64
# (24.0, 75.83, 0.17)
# 3.0    61.57
# 1.0    29.04
# 2.0     6.61
# 4.0     2.43
# NaN     0.35
# Name: PQ604-degree, dtype: float64
# (29.04, 6.61, 61.57, 2.43, 0.35)
# 3.0    43.83
# 4.0    34.43
# 2.0    12.00
# 5.0     5.22
# 1.0     4.52
# Name: PQ613, dtype: float64
# (4.52, 12.0, 43.83, 34.43, 5.22, 0)
# 6.0    63.65
# 2.0    12.52
# 1.0    12.17
# 3.0     5.04
# 4.0     4.35
# 5.0     2.09
# NaN     0.17
# Name: PQ605-major, dtype: float64
# (12.17, 12.52, 5.04, 4.35, 2.09, 63.65, 0.17)
# 3.0    28.70
# 4.0    24.17
# 5.0    18.26
# 6.0    14.96
# 7.0     5.91
# 1.0     5.39
# 2.0     1.39
# 8.0     1.22
# Name: PQ304-01, dtype: float64
# (5.39, 1.39, 28.7, 24.17, 18.26, 14.96, 5.91, 1.22, 0)
# (7.13, 92.87)

# %% [markdown]
# Нужно сделать такой алгоритм.
# 1. Написать функцию, которая подсчитывает количество вариантов ответа от 1 - 4
# 2. написать функцию, которая считает варианты ответа от 1 - 2
# 3. Написать функцию, которая считает ответил не ответил
# 4. Написать функцию, которая считает диапозоны.
# Алгоритм определяется максимальная и самая минимальная

# %%
# нужно для каждого теста сделать по каждой категории  какое количество ответов вышло
# нужно зафигачить алгоритм , который позволяет делать диапазоны
# нужно так же добавить эти данные 
# %clear

# %%
import pandas as pd
import yaml

with open('dictionary-psychologists.yml') as f:
    data = yaml.load(f, Loader=yaml.Loader)
    count_answer = []
    for d in data[7:]:
      try:
        a = d['Ответы']
        if len(a) == 4:
          print(a)
        if len(a) not in count_answer:
          print(d['Ключ'], len(a))
          count_answer.append(len(a))
      except KeyError:
        pass
        # print(d)
    print(count_answer)
# Out:
# {'Почти не уделяю этому время': 1, 'Немного времени уделяю': 2, 'Много времени уделяю': 3, 'Почти все время уделяю': 4}
# {'Почти не уделяю этому время': 1, 'Немного времени уделяю': 2, 'Много времени уделяю': 3, 'Почти все время уделяю': 4}
# PQ101-17 4
# {'Почти не уделяю этому время': 1, 'Немного времени уделяю': 2, 'Много времени уделяю': 3, 'Почти все время уделяю': 4}
# {'Почти не уделяю этому время': 1, 'Немного времени уделяю': 2, 'Много времени уделяю': 3, 'Почти все время уделяю': 4}
# {'Никогда': 1, 'Достаточно редко': 2, 'Достаточно часто': 3, 'Постоянно': 4}
# {'Никогда': 1, 'Достаточно редко': 2, 'Достаточно часто': 3, 'Постоянно': 4}
# {'Никогда': 1, 'Достаточно редко': 2, 'Достаточно часто': 3, 'Постоянно': 4}
# {'Никогда': 1, 'Достаточно редко': 2, 'Достаточно часто': 3, 'Постоянно': 4}
# {'Совершенно согласен': 1, 'Скорее согласен': 2, 'Скорее не согласен': 3, 'Совершенно не согласен': 4}
# ...

# %%
# %clear

# %%
# %clear

# %%
# Out:
#           x__subject__id___  ...  test_0__metadata_endTime
# 0                        id  ...          metadata.endTime
# 1  5cee09c905d7190ab5276fb2  ...  2019-05-29T04:43:02.218Z
# 2  5cee1961b2f7ce29f9a2e22b  ...  2019-05-29T06:04:47.407Z
# 3  5cee1b263ed9c329c57d7552  ...  2019-05-29T05:57:52.542Z
# 4  5cee1b582bd2d30ab4c00629  ...  2019-05-29T06:44:06.878Z
# 5  5cee1d2ab2f7ce29f9a2e22c  ...  2019-05-29T06:03:01.741Z
# 6  5cee2024b2f7ce29f9a2e22d  ...  2019-05-29T07:13:27.139Z
# 7  5cee208305d7190ab5276fb5  ...  2019-05-29T06:38:52.663Z
# 8  5cee25bab2f7ce29f9a2e231  ...  2019-05-29T06:47:14.277Z
# 9  5cee2c6e3ed9c329c57d7556  ...  2019-05-29T07:21:18.047Z
#
# [10 rows x 465 columns]
